# %% [markdown]
# # Load electra transformer for NER

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

ner_pipe = pipeline("token-classification", model="dbmdz/electra-large-discriminator-finetuned-conll03-english")
# Out:
# config.json:   0%|          | 0.00/828 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# # test it on a sentence

# %%
ner_pipe("hello my name is Motaz and I work with University of Salento")
# Out:
# [{'entity': 'I-PER',
#   'score': 0.99644536,
#   'index': 5,
#   'word': 'mo',
#   'start': 17,
#   'end': 19},
#  {'entity': 'I-PER',
#   'score': 0.9968177,
#   'index': 6,
#   'word': '##ta',
#   'start': 19,
#   'end': 21},
#  {'entity': 'I-PER',
#   'score': 0.99709284,
#   'index': 7,
#   'word': '##z',
#   'start': 21,
#   'end': 22},
#  {'entity': 'I-ORG',
#   'score': 0.9977223,
#   'index': 12,
#   'word': 'university',
#   'start': 39,
#   'end': 49},
#  {'entity': 'I-ORG',
#   'score': 0.98554534,
#   'index': 13,
#   'word': 'of',
#   'start': 50,
#   'end': 52},
#  {'entity': 'I-ORG',
#   'score': 0.9963731,
#   'index': 14,
#   'word': 'sale',
#   'start': 53,
#   'end': 57},
#  {'entity': 'I-ORG',
#   'score': 0.99781966,
#   'index': 15,
#   'word': '##nto',
#   'start': 57,
#   'end': 60}]
